# %%
pip install qrcode
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import qrcode

# %%
porfolio_link="https://nehakarki-35.github.io/"
qr_generate=qrcode.make(porfolio_link)
qr_generate

# %%
linkdin_link="https://www.linkedin.com/in/neha-karki-006b98391//"
qr_generate=qrcode.make(linkdin_link)
qr_generate

# %%
pip install qrcode
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import qrcode
from PIL import Image

linkdin_link = "https://www.linkedin.com/in/neha-karki-006b98391/"
qr_generate = qrcode.make(linkdin_link)
qr_generate

# %%
blogger_link="https://www.blogger.com/blog/posts/5344030094828133211"
qr_image=qrcode.make(blogger_link)
qr_image

# %%
insta_link="https://www.instagram.com/karki_35/"
qr_img=qrcode.make(insta_link)
qr_img

# %%
github_link="https://github.com/NehaKarki-35"
qr_img=qrcode.make(github_link)
qr_img

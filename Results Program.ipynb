# %%
 Student_name=input("enter student name:")
Roll_no=int(input("enter roll"))
Subject=["hindi","marks","science","sst","english"]
marks=[]
for sub in Subject:
    print(sub)
    m=int(input("enter any marks:"))
    marks.append(m)
Total_marks=sum(marks)
Percentage=Total_marks/len(marks)
for i in range(len(Subject)):
    print(Subject[i],marks[i])
    print("Total_marks",Total_marks)
print("percentage",Percentage)
passed=True
for m in marks:
    if m < 33:
        passed=False
if m > 33:
    print("pass")
else:
    print("false")
# Out:
# enter student name: Neha
# enter roll 2345678
# hindi
# enter any marks: 55
# marks
# enter any marks: 77
# science
# enter any marks: 55
# sst
# enter any marks: 88
# english
# enter any marks: 50
# hindi 55
# Total_marks 325
# marks 77
# Total_marks 325
# science 55
# Total_marks 325
# sst 88
# Total_marks 325
# english 50
# Total_marks 325
# percentage 65.0
# pass
